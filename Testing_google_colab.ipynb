# %%
import keras
import tensorflow as tf

from keras.models import Sequential, Model

from keras.datasets import mnist

from keras.layers import Dense, Dropout, Conv2D, BatchNormalization, MaxPool2D, Flatten
from keras.optimizers import SGD

from keras import utils

import numpy as np
# Out:
# Using TensorFlow backend.

# %%
batch_size = 100
n_inputs = 784
n_classes = 10
n_epochs = 10
#learning_rate = 0.01

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1],x_train.shape[2],1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],x_test.shape[2],1)

# %%
x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

# %%
x_train /= 255
x_test /= 255

# %%
y_train = utils.to_categorical(y_train, n_classes)
y_test = utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()

# %%
#@title
model.add(Conv2D(filters=64, kernel_size=3, activation='relu', input_shape = (28,28,1)))
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPool2D(3))
model.add(Dropout(0.1))
model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape = (28,28,1)))
model.add(Conv2D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPool2D(3))
model.add(Dense(units=128, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 16)          9232
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 16)          2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 16)          0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1, 128)         2176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 52,586
# Trainable params: 52,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
#learning_rate = 0.01
model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['accuracy'])

# %%
batch_size = 128
#n_inputs = 784
n_epochs = 50

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
keras.backend.set_session(sess)

model.fit(x_train, y_train, batch_size=batch_size, epochs=n_epochs)
# Out:
# Epoch 1/50
# 60000/60000 [==============================] - 11s 182us/step - loss: 2.3266 - acc: 0.1038
# Epoch 2/50
# 60000/60000 [==============================] - 10s 159us/step - loss: 2.3195 - acc: 0.1084
# Epoch 3/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 2.3093 - acc: 0.1180
# Epoch 4/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 2.2524 - acc: 0.1785
# Epoch 5/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 1.7368 - acc: 0.4383
# Epoch 31/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1479 - acc: 0.9552
# Epoch 32/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1444 - acc: 0.9563
# Epoch 33/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1394 - acc: 0.9583
# Epoch 34/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1370 - acc: 0.9586
# Epoch 35/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1336 - acc: 0.9590
# Epoch 36/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1282 - acc: 0.9612
# Epoch 37/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1261 - acc: 0.9624
# Epoch 38/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1231 - acc: 0.9629
# Epoch 39/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1200 - acc: 0.9640
# Epoch 40/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1183 - acc: 0.9640
# Epoch 41/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1147 - acc: 0.9654
# Epoch 42/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1124 - acc: 0.9655
# Epoch 43/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1095 - acc: 0.9671
# Epoch 44/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1067 - acc: 0.9679
# Epoch 45/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1035 - acc: 0.9687
# Epoch 46/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.1023 - acc: 0.9694
# Epoch 47/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1009 - acc: 0.9699
# Epoch 48/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0987 - acc: 0.9711
# Epoch 49/50
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0971 - acc: 0.9714
# Epoch 50/50
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0945 - acc: 0.9718

# %%
scores = model.evaluate(x_test, y_test)
print('\n loss:', scores[0])
print('\n accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 1s 129us/step
#
#  loss: 0.08626609891094267
#
#  accuracy: 0.9723

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
import os
os.listdir()

# %%
os.getcwd()

# %%
os.listdir('../gdrive/My Drive')
